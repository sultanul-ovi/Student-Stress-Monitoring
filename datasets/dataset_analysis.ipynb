# %% [markdown]
# - Dataset 01: [stressLevelDataset.csv](https://www.kaggle.com/datasets/rxnach/student-stress-factors-a-comprehensive-analysis/data)
# - Dataset 02: [student_depression_dataset.csv](https://www.kaggle.com/datasets/adilshamim8/student-depression-dataset)
# - Dataset 03: [Depression Student Dataset.csv](https://www.kaggle.com/datasets/ikynahidwin/depression-student-dataset)
# - Dataset 04: [student_lifestyle_dataset.csv](https://www.kaggle.com/datasets/steve1215rogg/student-lifestyle-dataset)
# - Dataset 05: [Stress Dataset.csv](https://www.kaggle.com/datasets/ashutoshsingh22102/stress-and-well-being-data-of-college-students)
# - Dataset 06: [mental_health_wearable_data.csv](https://www.kaggle.com/datasets/ziya07/mental-health-monitor-using-wearable-iot-sensors)
# - Dataset 07: [inside teen minds](https://www.kaggle.com/datasets/dakshbhatnagar08/inside-teen-minds-global-mental-health-and-habits)

# %% [markdown]
# ---

# %% [markdown]
# ### Dataset 01: Student Stress Factors: A Comprehensive Analysis
# #### Understanding the Underlying Causes and Their Impact on Today's Students
#
# #### 📘 About the Dataset:
# This dataset investigates the root causes of stress among students, derived from a nationwide survey. It includes around 20 key features grouped under five scientifically identified categories:
#
# #### 🧠 Psychological Factors
# - `anxiety_level`
# - `self_esteem`
# - `mental_health_history`
# - `depression`
#
# #### 🏥 Physiological Factors
# - `headache`
# - `blood_pressure`
# - `sleep_quality`
# - `breathing_problem`
#
# #### 🌆 Environmental Factors
# - `noise_level`
# - `living_conditions`
# - `safety`
# - `basic_needs`
#
# #### 🎓 Academic Factors
# - `academic_performance`
# - `study_load`
# - `teacher_student_relationship`
# - `future_career_concerns`
#
# #### 🤝 Social Factors
# - `social_support`
# - `peer_pressure`
# - `extracurricular_activities`
# - `bullying`
#
# ---

# %% [markdown]
# ### Dataset 02: Student Depression Dataset
# #### Analyzing Mental Health Trends and Predictors Among Students
#
# #### 📘 About the Dataset:
# This dataset explores the mental health status of students by analyzing demographic, academic, lifestyle, and psychological variables. It is ideal for building predictive models, identifying depression risk factors, and informing early intervention strategies. Each row represents a single student
#
# #### 🔑 Features:
#
# #### 🎓 Demographics
# - `id`: Unique student identifier
# - `Gender`: Male, Female, or Other
# - `Age`: Student's age in years
# - `City`: Location for geographic analysis
# - `Profession`: Field of study or work
# - `Degree`: Program or academic level
#
# #### 📚 Academic & Work Stress
# - `CGPA`: Academic performance indicator
# - `Academic Pressure`: Subjective stress level from academic demands
# - `Study Satisfaction`: Satisfaction with current study path
# - `Job Satisfaction`: Satisfaction with work, if employed
# - `Work Pressure`: Work-related stress level
# - `Work/Study Hours`: Average daily hours spent on academics or work
#
# #### 🧬 Lifestyle & Wellbeing
# - `Sleep Duration`: Average sleep in hours per day
# - `Dietary Habits`: Quality of eating and nutrition
# - `Financial Stress`: Level of financial strain
#
# #### 🧠 Mental Health Indicators
# - `Family History of Mental Illness`: Yes/No
# - `Have you ever had suicidal thoughts?`: Yes/No
# - `Depression`: **Target variable** (Yes/No) indicating presence of depression
#
# ---

# %% [markdown]
# ### Dataset 03: Depression Student Dataset
# #### Helping to detect someone's depression status
#
# #### 📘 About the Dataset:
# This dataset explores the relationship between mental health and factors such as demographics, academics, lifestyle, and family history. It is intended to help identify patterns linked to depression and support early detection or prevention strategies.
#
# ### 🗃️ Format:
# - CSV file with 502 entries
# - Each row represents one student
# - Mixed data types:
#   - Numerical Columns: 5
#   - Categorical Columns: 6
#
#
# ### 🔑 Feature Descriptions:
#
# #### 👤 Demographics
# - `Gender`: Student's gender (e.g., Male, Female)
# - `Age`: Numerical, student's age in years
#
# #### 📚 Academic Factors
# - `Academic Pressure`: Numeric indicator of academic stress
# - `Study Satisfaction`: Numeric rating of satisfaction with study path
# - `Study Hours`: Number of hours spent studying daily
#
# #### 🧬 Lifestyle Factors
# - `Sleep Duration`: Categorical (e.g., <6 hrs, 6–8 hrs, >8 hrs)
# - `Dietary Habits`: Categorical (e.g., Balanced, Irregular)
#
# #### 💰 Stress & Family History
# - `Financial Stress`: Numeric rating of financial burden
# - `Family History`: Categorical (Yes/No) indicating family mental illness history
#
# #### 🧠 Mental Health Indicators
# - `Suicidal Thoughts`: Categorical (Yes/No)
# - `Depression`: **Target variable** (Yes/No) indicating whether the student has depression
#
#
# ## 📊 Dataset Statistics:
#
# - Total Entries: **502**
# - Numerical Features: **5**
#   - `Age`, `Academic Pressure`, `Study Satisfaction`, `Study Hours`, `Financial Stress`
# - Categorical Features: **6**
#   - `Gender`, `Sleep Duration`, `Dietary Habits`, `Suicidal Thoughts`, `Family History`, `Depression`
#
# ---

# %% [markdown]
# ### Dataset 04: Student Lifestyle Dataset
# #### Subtitle: Daily Lifestyle and Academic Performance of Students
#
# ## 📘 About the Dataset:
# This dataset captures daily lifestyle patterns of students and their potential impact on academic performance, measured by CGPA. It includes 2,000 responses collected through a Google Form between August 2023 and May 2024, primarily from Indian students. The stress level is derived based on study and sleep hours.
#
# The data is suitable for education, psychology, health, and well-being research.
#
#
# ## 🗃️ File Information:
#
# - **File Name:** Daily_Lifestyle_and_Academic_Performance.csv
# - **File Format:** CSV
# - **Records:** 2,000 rows
# - **Columns:** 8
# - **Size:** ~150 KB
#
#
# ## 🔑 Column Descriptions:
#
# - `Student ID`: Unique identifier for each student
# - `Study Hours`: Number of hours spent studying per day
# - `Extracurricular Hours`: Daily hours spent on extracurricular activities
# - `Sleep Hours`: Average number of sleep hours per day
# - `Social Hours`: Daily time spent socializing
# - `Physical Activity Hours`: Time spent on physical activity per day
# - `Stress Level`: Derived metric based on study and sleep hours (scale not specified)
# - `CGPA`: Cumulative Grade Point Average (target variable for performance analysis)
#
# ---

# %% [markdown]
# ### Dataset 05: Stress and Well-being Data of College Students
# #### Survey on Stress and Well-being Factors Among College Students (Ages 18–21)
#
# #### 📘 About the Dataset:
# This dataset captures survey responses from 843 college students aged 18–21 regarding their experiences with stress, health, relationships, academics, and emotional well-being. The responses were collected via Google Forms using a five-point Likert scale ("Not at all" to "Extremely") and anonymized to protect privacy.
#
# It enables nuanced analysis of emotional and physical stress indicators and their correlations with academic performance and lifestyle factors.
#
#
# #### 🗃️ Technical Details:
#
# - **File Format:** CSV
# - **Total Records:** 843
# - **Age Range:** 18–21
# - **Gender Encoding:** 0 = Male, 1 = Female
# - **Rating Scale:** 5-point Likert scale
# - **Collection Tool:** Google Forms
# - **Personal Identifiers:** Removed for anonymity
#
# ## 🔑 Key Features (Selected):
#
# ### 👤 Demographic
# - `Gender`: Coded as 0 (Male), 1 (Female)
# - `Age`: Numeric age (18 to 21)
#
# ### 🧠 Emotional and Stress Indicators
# - `Have you recently experienced stress in your life?`
# - `Have you noticed a rapid heartbeat or palpitations?`
# - `Have you been dealing with anxiety or tension recently?`
# - `Do you face any sleep problems or difficulties falling asleep?`
# - `Do you have trouble concentrating on your academic tasks?`
# - `Have you been feeling sadness or low mood?`
# - `Do you get irritated easily?`
# - `Do you often feel lonely or isolated?`
#
# ### 🩺 Physical and Health Indicators
# - `Have you been getting headaches more often than usual?`
# - `Have you been experiencing any illness or health issues?`
# - `Have you gained/lost weight?`
#
# ### 📚 Academic & Environment Stressors
# - `Do you feel overwhelmed with your academic workload?`
# - `Are you in competition with your peers, and does it affect you?`
# - `Do you lack confidence in your academic performance?`
# - `Do you lack confidence in your choice of academic subjects?`
# - `Academic and extracurricular activities conflicting for you?`
# - `Do you attend classes regularly?`
# - `Are you facing any difficulties with your professors or instructors?`
# - `Is your working environment unpleasant or stressful?`
# - `Is your hostel or home environment causing you difficulties?`
#
# ### 💬 Social & Relationship Factors
# - `Do you find that your relationship often causes you stress?`
# - `Do you struggle to find time for relaxation and leisure activities?`
#
# ### 📌 Target Variable
# - `Which type of stress do you primarily experience?`: Eustress or Distress
#
# ---

# %% [markdown]
# ### Dataset 06: Mental Health Monitor Using Wearable IoT Sensors
# #### Subtitle: Data on Cognitive and Emotional States, EEG, GSR, and Student Demographics
#
# ## 📘 About the Dataset:
# This dataset supports the analysis and detection of mental health states (stress, anxiety, cognitive overload) using wearable IoT sensors. It includes readings from EEG and GSR sensors worn by students in different session contexts. The dataset enables modeling of mental health conditions in real time by linking sensor data with emotional and cognitive states.
#
#
#
# ## 🗃️ File Information:
#
# - **File Name:** mental_health_wearable_data.csv
# - **File Format:** CSV
# - **Total Records:** 500 rows
# - **File Size:** ~108 KB
# - **Sensors Used:** EEG (electroencephalogram), GSR (galvanic skin response)
#
#
#
# ## 🔑 Feature Descriptions:
#
# ### 🧬 Sensor Data
# - `delta`, `theta`, `alpha`, `beta`: EEG frequency band values representing different brain activity states
# - `GSR`: Galvanic skin response indicating emotional arousal or stress
#
# ### 🧠 Mental State Labels
# - `Cognitive State`: Categorical (Focused, Distracted, Cognitive Overload)
# - `Emotional State`: Categorical (Calm, Anxious, Stressed)
#
# ### 👤 Student Demographics
# - `ID`: Unique identifier
# - `Age`: Age of the student
# - `Gender`: Gender of the student
#
# ### 🕒 Session Context
# - `Session Type`: e.g., Study, Test, Relaxation
# - `Session Duration`: In minutes
# - `Environment`: e.g., Quiet Room, Library, Home
#
# ### ⚙️ Preprocessed Features
# - `ICA Components`, `Mean GSR`: Features derived from signal preprocessing
#
# ### 🎯 Target Variable
# - `Stress Label`: Binary target (1 = High Stress, 0 = Low Stress)
#
# ---

# %% [markdown]
# ### Dataset 07: Inside Teen Minds: Global Mental Health & Habits
# #### Subtitle: Daily Mood, Stress, Habits, and Coping – Across the Globe
#
# #### 📘 About the Dataset:
# This simulated dataset tracks the daily mental health, habits, and digital behaviors of 30,000 high school students from 40+ countries throughout 2025. It reflects how modern teens navigate school, stress, and productivity in a post-pandemic, AI-integrated world. The dataset offers a large-scale view of global teen behavior, ideal for mental health modeling and behavioral analysis.
#
#
# ## 🗃️ File Summary:
#
# - **Sample Size:** 30,000 unique students
# - **Geographic Coverage:** 40+ countries
# - **Time Frame:** Full year (daily logs, simulated for 2025)
# - **Data Type:** Time-series behavioral and mood tracking
# - **Total Records:** Likely millions (daily entries per student)
#
# ## 🔑 Key Features (Categories):
#
# ### 🧠 Mental Health & Mood
# - `Daily Mood`: Mood ratings on a normalized scale
# - `Stress Level`: Daily self-reported stress
# - `Anxiety Indicators`: Flags or scores for emotional unease
# - `Coping Methods`: Journaling, meditation, music, etc.
#
# ### 🛌 Sleep & Wellness
# - `Sleep Start` / `Sleep End`
# - `Total Sleep Hours`
# - `Sleep Quality Rating`
# - `Exercise Time`
#
# ### 📚 Study & Productivity
# - `Study Hours`
# - `Homework Completion Rate`
# - `Focus Level`
# - `Use of AI Tools`: ChatGPT, Gemini, Notion AI, etc.
# - `AI Use Purpose`: Study, therapy, organization, etc.
#
# ### 📱 Digital Behavior
# - `Screen Time Total`
# - `Social Media Usage (minutes)`
# - `Platform Breakdown`: TikTok, Instagram, Discord, etc.
#
# ### 👥 Social & Lifestyle
# - `Relationship Satisfaction`
# - `Family Time`
# - `Peer Interaction Time`
#
# ### 🌍 Demographic & Regional Info
# - `Student ID`
# - `Country`
# - `Timezone`
# - `Grade Level` or equivalent
#
# ---
